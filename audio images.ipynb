# %%
from keras_preprocessing.image import ImageDataGenerator
train = ImageDataGenerator(rescale= 1./255)
validation = ImageDataGenerator(rescale= 1./255)

# %%
train_dataset = train.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN/audio folders/audio pictures - 10 classes',
                                          target_size = (64,64),
                                          batch_size = 20,
                                          class_mode='categorical',
                                          shuffle = False)
validation_dataset = validation.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN/audio folders/testing data/test - audio pictures - 10 classes',
                                                    target_size = (64,64),
                                                    batch_size = 20,
                                                    class_mode='categorical',
                                                    shuffle = False)
# Out:
# Found 1000 images belonging to 10 classes.
# Found 300 images belonging to 10 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D, Flatten, Dense, Dropout

# %%
import keras
import numpy as np

# %%
import pandas as pd
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa
import librosa.display
import IPython.display
import random
import warnings
import os
from PIL import Image
import pathlib
import csv
# sklearn Preprocessing
from sklearn.model_selection import train_test_split
#Keras
import keras
import warnings
warnings.filterwarnings('ignore')
from keras import layers
from keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling1D, AveragePooling2D, Input, Add
from keras.models import Sequential
from keras.optimizers import SGD

# %%
model = Sequential()
input_shape=(64, 64, 3)#1st hidden layer
model.add(Conv2D(64, (3, 3), strides=(2, 2), input_shape=input_shape))
model.add(AveragePooling2D((2, 2), strides=(2,2)))

model.add(Activation('relu'))#2nd hidden layer
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(AveragePooling2D((2, 2), strides=(2,2)))

model.add(Activation('relu'))#3rd hidden layer
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(AveragePooling2D((2, 2), strides=(2,2)))

model.add(Activation('relu'))#Flatten
model.add(Flatten())

model.add(Dropout(rate=0.5))#Add fully connected layer.
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dropout(rate=0.5))#Output layer
model.add(Dense(10))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 31, 31, 64)        1792
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 64)        0
# _________________________________________________________________
# activation (Activation)      (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 15, 15, 64)        36928
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 7, 7, 64)          0
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          18464
# ...

# %%
model.compile(optimizer='sgd', loss= 'categorical_crossentropy', metrics=['accuracy'])

# %%
train_dataset.class_indices
# Out:
# {'blues': 0,
#  'classical': 1,
#  'country': 2,
#  'disco': 3,
#  'hiphop': 4,
#  'jazz': 5,
#  'metal': 6,
#  'pop': 7,
#  'reggae': 8,
#  'rock': 9}

# %%
len(train_dataset[3])
# Out:
# 2

# %%
model.fit_generator(train_dataset, steps_per_epoch =  train_dataset.samples//20,
                              epochs = 400)
# Out:
# Epoch 1/400
# 50/50 [==============================] - 226s 4s/step - loss: 2.2301 - accuracy: 0.2001
# Epoch 2/400
# 50/50 [==============================] - 9s 180ms/step - loss: 2.2741 - accuracy: 0.1541
# Epoch 3/400
# 50/50 [==============================] - 9s 177ms/step - loss: 2.3055 - accuracy: 0.0920
# Epoch 4/400
# 50/50 [==============================] - 9s 179ms/step - loss: 2.2980 - accuracy: 0.1284
# Epoch 5/400
# 50/50 [==============================] - 9s 177ms/step - loss: 2.3071 - accuracy: 0.0863
# Epoch 6/400
# 50/50 [==============================] - 9s 172ms/step - loss: 2.2990 - accuracy: 0.1219
# Epoch 7/400
# 50/50 [==============================] - 9s 177ms/step - loss: 2.2975 - accuracy: 0.1408
# Epoch 8/400
# 50/50 [==============================] - 9s 175ms/step - loss: 2.2988 - accuracy: 0.1191
# Epoch 9/400
# 50/50 [==============================] - 9s 176ms/step - loss: 2.2941 - accuracy: 0.1697
# Epoch 10/400
# ...

# %%
train_data = imagechanger.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/CNN/audio folders/audio pictures - 10 classes',
                            target_size = (64,64), batch_size = 100, class_mode='categorical')
# Out:
# Found 1000 images belonging to 10 classes.

# %%
train_data

# %%
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing.image import load_img
import cv2

img = image.load_img('/content/drive/MyDrive/Colab Notebooks/CNN/audio folders/audio pictures - 10 classes/blues/blues00000.png')
plt.imshow(img)

# %%
cv2.imread('/content/drive/MyDrive/Colab Notebooks/CNN/audio folders/audio pictures - 10 classes/blues/blues00000.png').shape
# Out:
# (288, 432, 3)

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
train = ImageDataGenerator(rescale= 1/255)
validation = ImageDataGenerator(rescale= 1/255)

# %%
train

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img

# load the image
img = load_img('/content/drive/MyDrive/Colab Notebooks/CNN/audio folders/audio pictures - 10 classes/blues/blues00000.png')
print("Orignal:" ,type(img))

# convert to numpy array
img_array = img_to_array(img)
print("NumPy array info:") 
print(type(img_array))    

print("type:",img_array.dtype)
print("shape:",img_array.shape)
# convert back to image

img_pil = array_to_img(img_array)
print("converting NumPy array:",type(img_pil))
# Out:
# Orignal: <class 'PIL.Image.Image'>
# NumPy array info:
# <class 'numpy.ndarray'>
# type: float32
# shape: (288, 432, 3)
# converting NumPy array: <class 'PIL.Image.Image'>

# %%
len(train_data[1])
# Out:
# 2

# %%
train_data.class_indices
# Out:
# {'blues': 0,
#  'classical': 1,
#  'country': 2,
#  'disco': 3,
#  'hiphop': 4,
#  'jazz': 5,
#  'metal': 6,
#  'pop': 7,
#  'reggae': 8,
#  'rock': 9}

# %%
answers=model.fit(train_data,epochs=100,verbose=2,batch_size=100)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-70-cd8e503fd44b> in <module>()
# ----> 1 answers=model.fit(train_data,epochs=100,verbose=2,batch_size=100)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ...
